# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import math
import os

import cv2
from PIL import Image
import numpy as np
from keras import layers
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg16 import VGG16
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D, Average, Input, Concatenate, GlobalMaxPooling2D,BatchNormalization
from tensorflow.keras.applications import ResNet50,MobileNet, DenseNet201, InceptionV3, NASNetLarge, InceptionResNetV2, NASNetMobile, DenseNet169
from keras.applications.xception import Xception
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
#from keras.optimizers import Adam
from keras.models import Model
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
from tqdm import tqdm
import tensorflow as tf
from keras import backend as K
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools


# %matplotlib inline

# %%
#Transfer 'jpg' images to an array IMG
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".png":
            img = read(PATH)
           
            img = cv2.resize(img, (RESIZE,RESIZE))
           
            IMG.append(np.array(img))
    return IMG

# %%
covid19_train = np.array(Dataset_loader('/content/drive/MyDrive/COVID-19 Radiography Database/train/COVID-19',224))
normal_train = np.array(Dataset_loader('/content/drive/MyDrive/COVID-19 Radiography Database/train/NORMAL',224))
pneumonia_train = np.array(Dataset_loader('/content/drive/MyDrive/COVID-19 Radiography Database/train/Viral Pneumonia',224))

covid19_test = np.array(Dataset_loader('/content/drive/MyDrive/COVID-19 Radiography Database/test/COVID-19',224))
normal_test = np.array(Dataset_loader('/content/drive/MyDrive/COVID-19 Radiography Database/test/NORMAL',224))
pneumonia_test = np.array(Dataset_loader('/content/drive/MyDrive/COVID-19 Radiography Database/test/Viral Pneumonia',224))
# Out:
# 100%|██████████| 194/194 [00:09<00:00, 20.87it/s]
# 100%|██████████| 1271/1271 [00:45<00:00, 27.95it/s]
# 100%|██████████| 1279/1279 [00:50<00:00, 25.15it/s]
# 100%|██████████| 25/25 [00:08<00:00,  3.10it/s]
# 100%|██████████| 90/90 [00:23<00:00,  3.80it/s]
# 100%|██████████| 95/95 [00:26<00:00,  3.57it/s]

# %%
print(len(normal_train))
print(len(covid19_train))
print(len(pneumonia_train))

print(len(normal_test))
print(len(covid19_test))
print(len(pneumonia_test))
# Out:
# 1271
# 194
# 1279
# 90
# 25
# 95

# %%
# Create labels
covid19_train_label   = np.full(len(covid19_train),0)
normal_train_label   = np.full(len(normal_train),1)
pneumonia_train_label = np.full(len(pneumonia_train),2)

covid19_test_label   = np.full(len(covid19_test),0)
normal_test_label   = np.full(len(normal_test),1)
pneumonia_test_label = np.full(len(pneumonia_test),2)

# %%
# Merge data 
X_train = np.concatenate((covid19_train, normal_train, pneumonia_train), axis = 0)
Y_train = np.concatenate((covid19_train_label, normal_train_label, pneumonia_train_label), axis = 0)
X_test = np.concatenate((covid19_test, normal_test, pneumonia_test), axis = 0)
Y_test = np.concatenate((covid19_test_label, normal_test_label, pneumonia_test_label), axis = 0)

# %%
# Shuffle train data
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
Y_train = Y_train[s]

# Shuffle test data
s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
Y_test = Y_test[s]

# %%
# To categorical
Y_train = to_categorical(Y_train, num_classes= 3)
Y_test = to_categorical(Y_test, num_classes= 3)

# %%
x_train, x_val, y_train, y_val = train_test_split(
    X_train, Y_train, 
    test_size=0.2, 
    random_state=11
)

# %%
# # Display first 15 images of moles, and how they are classified
w=60
h=40
fig=plt.figure(figsize=(10,10))
columns = 4
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if np.argmax(Y_train[i]) == 0:
        ax.title.set_text('Covid19')
    elif np.argmax(Y_train[i]) == 1:
        ax.title.set_text('Normal')
    elif np.argmax(Y_train[i]) == 2:
        ax.title.set_text('Pneumonia')
    plt.imshow(x_train[i], interpolation='nearest')
plt.show()

# %%
BATCH_SIZE = 32

# Using original generator
train_generator = ImageDataGenerator(
        zoom_range=2.5,  # set range for random zoom
        rotation_range = 90,
        shear_range = 0.5,
        width_shift_range=0.5,
        height_shift_range=0.5,
        horizontal_flip=True,  # randomly flip images
        vertical_flip=True  # randomly flip images
    )

# %%
IMAGE_SIZE=224
# Model
input_shape = (IMAGE_SIZE, IMAGE_SIZE, 3)
inputs = Input(input_shape)
 
vgg      = DenseNet169(include_top=False, input_shape=input_shape)(inputs)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51879936/51877672 [==============================] - 0s 0us/step
# 51888128/51877672 [==============================] - 0s 0us/step

# %%
from tensorflow.keras.optimizers import SGD, RMSprop, Adam
outputs = GlobalAveragePooling2D()(vgg)
outputs = Dropout(0.4)(outputs)
outputs = BatchNormalization()(outputs)
outputs = Dense(256,activation='relu')(outputs) 
outputs = Dense(128,activation='relu')(outputs) 
outputs = Dropout(0.2)(outputs)
outputs = Dense(3, activation='softmax')(outputs)

model = Model(inputs, outputs)
model.compile(optimizer=Adam(lr=0.0001, decay=0.00001),
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  densenet169 (Functional)    (None, 7, 7, 1664)        12642880
#
#  global_average_pooling2d (G  (None, 1664)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1664)              0
#
#  batch_normalization (BatchN  (None, 1664)             6656
#  ormalization)
#
#  dense (Dense)               (None, 256)               426240
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 13,109,059
# Trainable params: 12,947,331
# Non-trainable params: 161,728
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# Learning Rate Reducer
learn_control = ReduceLROnPlateau(monitor='val_acc', patience=5,
                                  verbose=1,factor=0.2, min_lr=1e-7)

# Checkpoint
filepath="/content/drive/MyDrive/writing.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %%
history = model.fit_generator(
    train_generator.flow(x_train, y_train, batch_size=BATCH_SIZE),
    steps_per_epoch=x_train.shape[0] / BATCH_SIZE,
    epochs=150,
    validation_data=(x_val, y_val),
    callbacks=[learn_control, checkpoint]
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/150
# 69/68 [==============================] - ETA: 0s - loss: 0.4522 - accuracy: 0.7021WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 68/68 [==============================] - 116s 1s/step - loss: 0.4522 - accuracy: 0.7021 - val_loss: 0.3282 - val_accuracy: 0.7814 - lr: 1.0000e-04
# Epoch 2/150
# 69/68 [==============================] - ETA: 0s - loss: 0.3143 - accuracy: 0.8196WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 68/68 [==============================] - 68s 989ms/step - loss: 0.3143 - accuracy: 0.8196 - val_loss: 0.5994 - val_accuracy: 0.6794 - lr: 1.0000e-04
# Epoch 3/150
# 69/68 [==============================] - ETA: 0s - loss: 0.2690 - accuracy: 0.
ARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 68/68 [==============================] - 68s 984ms/step - loss: 0.1070 - accuracy: 0.9380 - val_loss: 0.0867 - val_accuracy: 0.9672 - lr: 1.0000e-04
# Epoch 134/150
# 69/68 [==============================] - ETA: 0s - loss: 0.0994 - accuracy: 0.9449WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 68/68 [==============================] - 68s 983ms/step - loss: 0.0994 - accuracy: 0.9449 - val_loss: 0.0859 - val_accuracy: 0.9490 - lr: 1.0000e-04
# Epoch 135/150
# 69/68 [==============================] - ETA: 0s - loss: 0.0947 - accuracy: 0.9449WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 68/68 [==============================] - 68s 984ms/step - loss: 0.0947 - accuracy: 0.9449 - val_loss: 0.3751 - val_accuracy: 0.7596 - lr: 1.0000e-04
# Epoch 136/150
# 69/68 [==============================] - ETA: 0s - loss: 0.1055 - accuracy: 0.9408WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 68/68 [==============================] - 68s 985ms/step - loss: 0.1055 - accuracy: 0.9408 - val_loss: 0.1229 - val_accuracy: 0.9235 - lr: 1.0000e-04
# Epoch 137/150
# 69/68 [==============================] - ETA: 0s - loss: 0.0984 - accuracy: 0.9421WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 68/68 [==============================] - 68s 983ms/step - loss: 0.0984 - accuracy: 0.9421 - val_loss: 0.0899 - val_accuracy: 0.9490 - lr: 1.0000e-04
# Epoch 138/150
# 69/68 [==============================] - ETA: 0s - loss: 0.0942 - accuracy: 0.9476WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 68/68 [==============================] - 68s 983ms/step - loss: 0.0942 - accuracy: 0.9476 - val_loss: 0.1292 - val_accuracy: 0.9417 - lr: 1.0000e-04
# Epoch 139/150
# 69/68 [==============================] - ETA: 0s - loss: 0.1004 - accuracy: 0.9462WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 68/68 [==============================] - 69s 995ms/step - loss: 0.1004 - accuracy: 0.9462 - val_loss: 0.2086 - val_accuracy: 0.8925 - lr: 1.0000e-04
# Epoch 140/150
# 69/68 [==============================] - ETA: 0s - loss: 0.1146 - accuracy: 0.9294WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 68/68 [==============================] - 68s 984ms/step - loss: 0.1146 - accuracy: 0.9294 - val_loss: 0.1488 - val_accuracy: 0.9071 - lr: 1.0000e-04
# Epoch 141/150
# 69/68 [==============================] - ETA: 0s - loss: 0.0988 - accuracy: 0.9485WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 68/68 [==============================] - 68s 983ms/step - loss: 0.0988 - accuracy: 0.9485 - val_loss: 1.2029 - val_accuracy: 0.4372 - lr: 1.0000e-04
# Epoch 142/150
# 69/68 [==============================] - ETA: 0s - loss: 0.1050 - accuracy: 0.9435WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 68/68 [==============================] - 68s 983ms/step - loss: 0.1050 - accuracy: 0.9435 - val_loss: 0.2284 - val_accuracy: 0.8361 - lr: 1.0000e-04
# Epoch 143/150
# 69/68 [==============================] - ETA: 0s - loss: 0.1005 - accuracy: 0.9435WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 68/68 [==============================] - 68s 984ms/step - loss: 0.1005 - accuracy: 0.9435 - val_loss: 0.0599 - val_accuracy: 0.9672 - lr: 1.0000e-04
# Epoch 144/150
# 69/68 [==============================] - ETA: 0s - loss: 0.0970 - accuracy: 0.9412WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 68/68 [==============================] - 68s 984ms/step - loss: 0.0970 - accuracy: 0.9412 - val_loss: 0.1073 - val_accuracy: 0.9472 - lr: 1.0000e-04
# Epoch 145/150
# 69/68 [==============================] - ETA: 0s - loss: 0.1012 - accuracy: 0.9426WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 68/68 [==============================] - 68s 982ms/step - loss: 0.1012 - accuracy: 0.9426 - val_loss: 0.4310 - val_accuracy: 0.7450 - lr: 1.0000e-04
# Epoch 146/150
# 69/68 [==============================] - ETA: 0s - loss: 0.1035 - accuracy: 0.9408WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 68/68 [==============================] - 68s 992ms/step - loss: 0.1035 - accuracy: 0.9408 - val_loss: 0.2063 - val_accuracy: 0.8725 - lr: 1.0000e-04
# Epoch 147/150
# 69/68 [==============================] - ETA: 0s - loss: 0.0945 - accuracy: 0.9462WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 68/68 [==============================] - 68s 984ms/step - loss: 0.0945 - accuracy: 0.9462 - val_loss: 0.1716 - val_accuracy: 0.9271 - lr: 1.0000e-04
# Epoch 148/150
# 69/68 [==============================] - ETA: 0s - loss: 0.1040 - accuracy: 0.9394WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 68/68 [==============================] - 68s 985ms/step - loss: 0.1040 - accuracy: 0.9394 - val_loss: 0.2156 - val_accuracy: 0.8780 - lr: 1.0000e-04
# Epoch 149/150
# 69/68 [==============================] - ETA: 0s - loss: 0.0941 - accuracy: 0.9449WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 68/68 [==============================] - 68s 988ms/step - loss: 0.0941 - accuracy: 0.9449 - val_loss: 0.0828 - val_accuracy: 0.9454 - lr: 1.0000e-04
# Epoch 150/150
# 69/68 [==============================] - ETA: 0s - loss: 0.1040 - accuracy: 0.9408WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 68/68 [==============================] - 68s 986ms/step - loss: 0.1040 - accuracy: 0.9408 - val_loss: 0.0807 - val_accuracy: 0.9454 - lr: 1.0000e-04

# %%
Y_pred = model.predict(X_test)

# %%
Y_pred = model.predict(X_test)
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))

cm_plot_label =['Covid19','Normal','Pneumonia']
plot_confusion_matrix(cm, cm_plot_label, title ='Multiclass Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[25  0  0]
#  [ 0 80 10]
#  [ 3  3 89]]

# %%
pred=model.predict(X_test)
Y_pred = np.argmax(pred, 1)
Y_test=np.argmax(Y_test,1)
import numpy as np
from sklearn import metrics
fpr, tpr, thresholds = metrics.roc_curve(Y_test, Y_pred, pos_label=2)
auc=metrics.auc(fpr, tpr)
auc
# Out:
# 0.917391304347826

# %%
plt.plot([0, 1], [0, 1], 'r--')
plt.plot(fpr, tpr, label='AUC = {:.3f}'.format(auc))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
#plt.savefig(ROC_PLOT_FILE, bbox_inches='tight')
plt.close()

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('DenseNet169 Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,151))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.grid()
ax1.set_xticks(np.arange(1, 151, 5))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.grid()
ax2.set_xticks(np.arange(1, 151, 5))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
pred=model.predict(X_test)
Y_pred = np.argmax(pred, 1)
y_test=np.argmax(Y_test,1)
from sklearn.metrics import classification_report, confusion_matrix
print('Classification Report')
target_names = ['Covid19','Normal','Pneumonia']
print(classification_report(y_test, Y_pred, target_names=target_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#      Covid19       0.89      1.00      0.94        25
#       Normal       0.96      0.89      0.92        90
#    Pneumonia       0.90      0.94      0.92        95
#
#     accuracy                           0.92       210
#    macro avg       0.92      0.94      0.93       210
# weighted avg       0.93      0.92      0.92       210
